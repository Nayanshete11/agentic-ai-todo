# %% [markdown]
# <a href="https://colab.research.google.com/github/Nayanshete11/agentic-ai-todo/blob/main/CHATBOT_WITH_RULE_BASED_RESPONSES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Rule-Based Chatbot

print("🤖 Chatbot: Hello! I am a Rule-Based Chatbot.")
print("Type 'bye' to end the conversation.\n")

while True:

    # Take input from user
    user_input = input("You: ").lower()

    # Rule 1 - Greeting
    if user_input == "hello" or user_input == "hi":
        print("Chatbot: Hello! How can I help you today?")

    # Rule 2 - Asking about chatbot
    elif user_input == "who are you":
        print("Chatbot: I am a simple rule-based chatbot created using Python.")

    # Rule 3 - Asking about health
    elif user_input == "how are you":
        print("Chatbot: I am doing great! Thanks for asking.")

    # Rule 4 - Asking name
    elif user_input == "your name":
        print("Chatbot: My name is RuleBot.")

    # Rule 5 - Asking purpose
    elif user_input == "what can you do":
        print("Chatbot: I can answer simple questions based on predefined rules.")

    # Rule 6 - Asking about AI
    elif user_input == "what is ai":
        print("Chatbot: AI stands for Artificial Intelligence. It allows machines to simulate human intelligence.")

    # Rule 7 - Help command
    elif user_input == "help":
        print("Chatbot: You can ask me things like 'hello', 'who are you', 'what is ai'.")

    # Rule 8 - Exit condition
    elif user_input == "bye":
        print("Chatbot: Goodbye! Have a nice day.")
        break

    # Default response
    else:
        print("Chatbot: Sorry, I don't understand that. Please try another question.")
# Out:
# 🤖 Chatbot: Hello! I am a Rule-Based Chatbot.
# Type 'bye' to end the conversation.
#
# Chatbot: Hello! How can I help you today?
# Chatbot: Sorry, I don't understand that. Please try another question.
# Chatbot: AI stands for Artificial Intelligence. It allows machines to simulate human intelligence.
